# %%
function GMRES_IR(A, b; ul = Float16, u = Float32, ur = Float64, up = Float16, ug = Float32, imax=10, atol=1e-6)\
    
    # Step 1: factorization in ul precision
    LU = lu(ul.(A))

    # Step 2: solve x in ul precision
    x = LU \ ul.(b) # should I keep x in higher precision after the operation? 

    for i in 1:imax
        # Step 3: residual in ur precision
        r = ur.(b) - ur.(A) * ur.(x)

        # Step 4: correction in ug precision
        P = (up.(LU.U) \ (up.(LU.L) \ I)) * up.(A)
        p = (ug.(LU.U) \ (ug.(LU.L) \ I)) * ug.(r)

        d, _ = gmres(P, p)
        println(d)

        # Step 5: update in u precision
        x = u.(x) + u.(d)

    end

    return x
end
# Out:
# GMRES_IR (generic function with 1 method)

# %%
function example(n, m; ul = Float16, u = Float32, ur = Float64, imax=10, atol=1e-6)

    A = rand(n, m)
    b = rand(n)

    start_time = time()
    x_true = A \ b
    elapsed = time() - start_time
    x_true = vec(x_true)
    println("Run time: ", elapsed)

    start_time = time()
    x = GMRES_IR(A, b)
    elapsed = time() - start_time
    println("Run time: ", elapsed)
    
    error = abs(norm(x-x_true))
    println("Error: ", error)
    

end
# Out:
# example (generic function with 1 method)

# %%
using LinearAlgebra
using BenchmarkTools
using IterativeSolvers

example(100, 100)
# Out:
# Run time: 0.04897189140319824
# 0.007842871
# MethodError: no method matching +(::Vector{Float32}, ::Float32)
# For element-wise addition, use broadcasting with dot syntax: array .+ scalar
# The function `+` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   +(::Any, ::Any, ::Any, ::Any...)
#    @ Base operators.jl:596
#   +(::Bool, ::T) where T<:AbstractFloat
#    @ Base bool.jl:173
#   +(::Missing, ::Number)
#    @ Base missing.jl:123
#   ...
#
#
# Stacktrace:
#  [1] GMRES_IR(A::Matrix{Float64}, b::Vector{Float64}; ul::Type, u::Type, ur::Type, up::Type, ug::Type, imax::Int64, atol::Float64)
#    @ Main ./In[58]:21
#  [2] GMRES_IR
#    @ ./In[58]:1 [inlined]
#  [3] example(n::Int64, m::Int64; ul::Type, u::Type, ur::Type, imax::Int64, atol::Float64)
#    @ Main ./In[60]:13
#  [4] example(n::Int64, m::Int64)
#    @ Main ./In[60]:1
#  [5] top-level scope
#    @ In[62]:5
